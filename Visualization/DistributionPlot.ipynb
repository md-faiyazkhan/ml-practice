# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We use distribution plots to visualize the distribution of quantitative data.
#
# ## Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
#
# * displot/histplot
# * jointplot
# * pairplot
# * rugplot
#
# ---
#
# ## Q. What is the difference between Quantitative and Qualitative data?
# ## Ans:
# ### **Quantitative Data**
#
# * **Numeric** data (numbers).
# * Measure kiya ja sakta hai.
# * Example: Height = 170 cm, Age = 23, Salary = 50k.
# * Further types: **Discrete** (countable, like number of students) & **Continuous** (measurable, like weight).
#
# ### **Qualitative Data**
#
# * **Categorical / Descriptive** data (non-numeric).
# * Describe karta hai quality/characteristics.
# * Example: Gender = Male/Female, Color = Red/Blue, City = Kolkata.
# * Further types: **Nominal** (no order, like colors) & **Ordinal** (order matters, like ranking).
#
# ### **Key Difference**
#
# * Quantitative → *"How much / How many?"* (numbers).
# * Qualitative → *"What type / Which category?"* (labels).
#
# 👉 Simple: **Quantitative = numbers, Qualitative = categories.**

# %%
df = sns.load_dataset('tips')  # Seaborns inbuilt Dataset. You can check on Seaborn official Github Repo for more Inbuilt Datasets.
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %% [markdown]
# # 1. Dis/Hist (Distribution/Histogram Plot)
# ### Recommended: Use Histplot()

# %%
sns.displot(df['total_bill'])  # Distribution Plot as Histogram

# %%
sns.histplot(df['total_bill'])  # displot and hisplot both work same
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# We can manage Building Box count Manually by using 'bins'
sns.histplot(df['total_bill'], bins=20)  # building box count is 20 after using 'bins=20'
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# KDE (Kernal Density Estimation)
# This help us to check the 'density curve' as 'left Skewd' 'Right skewd' or 'Normal Distribution' 
sns.histplot(df['total_bill'], bins=20, kde=True)   # kde=True is as 'on' or false is like 'off' Kde=True/False==on/off
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Making Subplot Histogram for 2 different columns 1.'total_bill' 2.'tip'
plt.subplot(1,2,1)  # plot 1
sns.histplot(df['total_bill'], bins=20, kde=True)  # Histogram of Plot 1
plt.subplot(1,2,2)  # plot 2
sns.histplot(df['tip'], bins=20, kde=True)  # Histogram of Plot 2
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # 2. Joint Plot

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data=df)  # the plot would show as 'scatter' its because of an function call 'kind'. by default it sets kind=scatter.

# %%
# hexa plot
sns.jointplot(x = 'total_bill', y = 'tip', data=df, kind='hex')  # kind=hex for hex plot. press shift+tab for more information.

# %%
# KDE (Kernal Density Estimation) Plot 
sns.jointplot(x = 'total_bill', y = 'tip', data=df, kind='kde')  # kind=kde for KDE plot. press shift+tab for more information.

# %%
# Regression Plot
sns.jointplot(x = 'total_bill', y = 'tip', data=df, kind='reg')  # kind=reg for hex plot. press shift+tab for more information.

# %% [markdown]
# # 3. Pair Plot
# ---
# ## **What is Pairplot?**
#
# * A **figure-level function** in Seaborn (`sns.pairplot()`).
# * Shows **pairwise relationships** among all numerical features in a dataset.
# * Off-diagonal → **scatter plots** (x vs y for every pair).
# * Diagonal → **distribution plots** (histogram or KDE for each variable).
# ---
# ## **When & Why to use?**
#
# * **When:** To quickly visualize the relationships among multiple numerical columns in one view.
# * **Why:**
#
#   * To understand correlations between variables.
#   * To detect outliers.
#   * For quick insights during **Exploratory Data Analysis (EDA)**.
#   * To compare categories (using the `hue` parameter).
#
# 👉 In short: **Pairplot = a quick EDA tool to visualize pairwise relationships between all numeric variables in a dataset.**

# %%
sns.pairplot(df)  # Shows pairwise relationships among all numerical features(columns) in a dataset

# %%
sns.pairplot(df, hue='sex')   # hue → divides data category-wise using different colors for each group.

# %%
sns.pairplot(df, hue='size', palette='rainbow')   # hue='size', size is an column. palette is a set of color, and rainbow is an inbuilt set of color

# %% [markdown]
# # 4. Rug Plot

# %%
sns.rugplot(df)
# Out:
# <Axes: >
