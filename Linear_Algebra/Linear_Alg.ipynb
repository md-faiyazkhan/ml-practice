# %%
import numpy as np

# %%
# Define matrices 
A = np.array([[1, 2, 3],
              [4, 5, 6]])

B = np.array([[10, 11],
              [20, 21],
              [30, 31]])

# %%
A 
B
# Out:
# array([[10, 11],
#        [20, 21],
#        [30, 31]])

# %%
# Simple Multiplication 
A @ B
# Out:
# array([[140, 146],
#        [320, 335]])

# %% [raw]
# # Hadamar Multiplication
#
# code:
# A * B   # Hadamard is not possible due to unmatched matrix shapes. Hadamard requires same shape.

# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

print("Normal Multiplication (@):\n", A @ B)
print("Hadamard Multiplication (*):\n", A * B)
# Out:
# Normal Multiplication (@):
#  [[19 22]
#  [43 50]]
# Hadamard Multiplication (*):
#  [[ 5 12]
#  [21 32]]

# %% [raw]
# A = np.array([[1, 2],
#               [3, 4]])
#
# B = np.array([[5, 6],
#               [7, 8]])
#
#
# print("Matrix Multiplication (Row × Column):")
# print(A @ B)
#
# [[19, 22],    ← Row-0 × Columns
#  [43, 50]]    ← Row-1 × Columns
#
#
#
# print("\nHadamard (Element × Element):")
# print(A * B)
#
# [[5, 12],     ← Position-wise
#  [21, 32]]

# %%
# Transpose of Matrix (A)
A.T   # if it is row vector, then it will convert into column vector but if it is column vector, it will convert into row vector
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
# Transpose of Matrix (B)
B.T   # if it is row vector, then it will convert into column vector but if it is column vector, it will convert into row vector
# Out:
# array([[5, 7],
#        [6, 8]])
