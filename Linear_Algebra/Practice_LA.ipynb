# %%
import numpy as np
import pandas as pd

# %% [raw]
# Create a Matrix of size 3*3 (3 rows and 3 colums).Perform the following Operation:
#
# A)Add 50 to your matrix
#
# B)Subtract 20 in your matrix
#
# C)Multiply 3 in your matrix
#
# D)Divide your matrix by 4.

# %%
# Creating a Matrix
M1 = np.random.randint(10, 50, size=(3, 3))

# %%
M1
# Out:
# array([[21, 40, 23],
#        [38, 27, 49],
#        [36, 46, 26]], dtype=int32)

# %%
# Task A- Adding 50 to Matrix
M1+50   # this operation will not reflect to the original Matrix (M1)
# Out:
# array([[71, 90, 73],
#        [88, 77, 99],
#        [86, 96, 76]], dtype=int32)

# %%
# Task B- Subtracting 20 from Matrix
M1-20   # this operation will not reflect to the original Matrix (M1)
# Out:
# array([[ 1, 20,  3],
#        [18,  7, 29],
#        [16, 26,  6]], dtype=int32)

# %%
# Task C- Multiplying Matrix with 3 
M1*3   # this operation will not reflect to the original Matrix (M1)
# Out:
# array([[ 63, 120,  69],
#        [114,  81, 147],
#        [108, 138,  78]], dtype=int32)

# %%
# Task D- Deviding Matrix by 4 
M1/4   # this operation will not reflect to the original Matrix (M1)
# Out:
# array([[ 5.25, 10.  ,  5.75],
#        [ 9.5 ,  6.75, 12.25],
#        [ 9.  , 11.5 ,  6.5 ]])

# %% [markdown]
# ### Task: Create two 3*3 matrices and then perform additon,subtraction,multiplication and division between these two metrices.

# %%
# Creating 2 more Matrix
M2 = np.random.randint(10, 50, size= (3, 3))
M3 = np.random.randint(10, 50, size= (3, 3))

# %%
M2
# Out:
# array([[35, 46, 21],
#        [40, 38, 27],
#        [42, 26, 16]], dtype=int32)

# %%
M3
# Out:
# array([[45, 47, 22],
#        [42, 13, 26],
#        [18, 46, 10]], dtype=int32)

# %%
# Task: Performing Addition between these Two Matrix
M2+M3
# Out:
# array([[80, 93, 43],
#        [82, 51, 53],
#        [60, 72, 26]], dtype=int32)

# %%
# Task: Performing Subtraction between these Two Matrix
M2-M3
# Out:
# array([[-10,  -1,  -1],
#        [ -2,  25,   1],
#        [ 24, -20,   6]], dtype=int32)

# %%
# Task: Performing Multiplication between these Two Matrix
M2*M3
# Out:
# array([[1575, 2162,  462],
#        [1680,  494,  702],
#        [ 756, 1196,  160]], dtype=int32)

# %%
# Task: Performing Division between these Two Matrix
M2/M3
# Out:
# array([[0.77777778, 0.9787234 , 0.95454545],
#        [0.95238095, 2.92307692, 1.03846154],
#        [2.33333333, 0.56521739, 1.6       ]])

# %% [markdown]
# ### Task: Perform dot product between two matrix of size(2*2).

# %%
# Creating 2x2 Matrix
M1=np.array([[12,14],[10,8]])
M2=np.array([[1,4],[20,16]])

print(M1)
print(M2)
# Out:
# [[12 14]
#  [10  8]]
# [[ 1  4]
#  [20 16]]

# %%
# Performing Dot Product between created 2x2 Matrix
dot_prod = np.dot(M1,M2)
print(dot_prod)
# Out:
# [[292 272]
#  [170 168]]

# %% [markdown]
# ## **Note:** Columns of first matrix must be equal to rows of second matrix

# %% [markdown]
# # **Tanspose of the Metrix**
# ### Task: Create a 3*3 Matrix and perform its Tanspose.

# %%
# Creating a Matrix of 3*3
M1 = np.random.randint(10, 50, size= (3, 3))

# %%
M1
# Out:
# array([[17, 40, 41],
#        [33, 32, 32],
#        [28, 49, 21]], dtype=int32)

# %%
# Perform Task: Transpose 
trans_M1 = M1.T

# %%
trans_M1
# Out:
# array([[17, 33, 28],
#        [40, 32, 49],
#        [41, 32, 21]], dtype=int32)

# %% [markdown]
# ## **Property 1: Tanspose of a Transposed matrix is the original Matrix**

# %%
# Transpose of a Transposed Matrix
trans_M1.T
# Out:
# array([[17, 40, 41],
#        [33, 32, 32],
#        [28, 49, 21]], dtype=int32)

# %% [markdown]
# ## **Property 2: (Additive Property): (A+B).T = A.T + B.T**

# %%
A = np.array([[4,5],[3,8],[20,30]])
B = np.array([[12,14],[45,5],[9,8]])

x = (A+B).T
print(x)

y = A.T+B.T
print(y)

if np.array_equal(x,y):
  print("Additive property is True")

else:
  print("Additive Property id False")
# Out:
# [[16 48 29]
#  [19 13 38]]
# [[16 48 29]
#  [19 13 38]]
# Additive property is True

# %% [markdown]
# ## **Property 3: Multiplication Property of the transpose: (AxB).T = B.T x A.T**

# %%
A = np.array([[4,3,1],[8,9,6],[7,5,7]])
B = np.array([[1,2,7],[3,4,5],[5,6,9]])

x = np.dot(A,B).T
print(x)
print()

y = B.T.dot(A.T)
print(y)

if np.array_equal(x,y):
  print("Multiplicative property is True")

else:
  print("Multiplicative Property id False")
# Out:
# [[ 18  65  57]
#  [ 26  88  76]
#  [ 52 155 137]]
#
# [[ 18  65  57]
#  [ 26  88  76]
#  [ 52 155 137]]
# Multiplicative property is True

# %% [markdown]
# # **Determinant**

# %% [raw]
# To find the determinant the matrix should be square(rows and columns be shape).
#
# If det!=0,Matrix is Invertible
#
# If det=0,Matrix is Not Invertible.
#
# Create a 3*3 matrix and find the determinant of the matrix.

# %%
M1 = np.random.randint(10, 50, size= (3, 3))
M1
# Out:
# array([[11, 22, 32],
#        [15, 16, 13],
#        [18, 41, 41]], dtype=int32)

# %%
# To find Detreminant
np.linalg.det(M1)
# Out:
# np.float64(3434.9999999999995)

# %% [markdown]
# # **Inverse**

# %%
# Tp find the inverse
M1_inv = np.linalg.inv(M1)

# %%
M1_inv
# Out:
# array([[ 0.03580786,  0.11935953, -0.0657933 ],
#        [-0.11091703, -0.0363901 ,  0.09810771],
#        [ 0.09519651, -0.01601164, -0.04483261]])

# %%
np.round(M1 @ M1_inv, decimals= 4)
# Out:
# array([[ 1.,  0., -0.],
#        [-0.,  1., -0.],
#        [ 0., -0.,  1.]])

# %% [markdown]
# # **Rank**
#
# The number of independent rows or colums in matrix.

# %%
A = np.array([[1,2],[2,4]])
np.linalg.matrix_rank(A)
# Out:
# np.int64(1)

# %%
A = np.array([[1,2],[5,6]])
np.linalg.matrix_rank(A)
# Out:
# np.int64(2)

# %% [markdown]
# # **Eigen Values and Eigen Vectors**

# %%
A = np.array([[1,5],[3,2]])
eigVal,eigVec = np.linalg.eig(A)

# %%
eigVal
# Out:
# array([-2.40512484,  5.40512484])

# %%
eigVec
# Out:
# array([[-0.82653237, -0.75033198],
#        [ 0.56288918, -0.66106121]])
