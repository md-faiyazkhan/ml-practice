# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
penguins = sns.load_dataset('penguins')

# %%
# Show first 5 rows
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Create scatter plot
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', style='sex')

# Add title and labels
plt.title('Penguin Bill Length vs Bill Depth')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')

# Show the plot
plt.show()

# %%
# Scatter plot with regression line: body mass vs flipper length
plt.figure(figsize=(8,5))

sns.regplot(data=penguins, x='flipper_length_mm', y='body_mass_g', scatter_kws={'s':50}, line_kws={'color':'red'})

# Add title and labels
plt.title('Body Mass vs Flipper Length with Regression Line')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')

# Show the plot
plt.show()

# %%
# Box plot of body mass per species (Fixed for future versions)
plt.figure(figsize=(8,5))

sns.boxplot(
    data=penguins,
    x='species',
    y='body_mass_g',
    hue='species',          # Fix: Assign x variable as hue
    palette='Set2',
    legend=False            # Fix: Hide duplicate legend
)

# Add title and labels
plt.title('Body Mass Distribution per Penguin Species')
plt.xlabel('Species')
plt.ylabel('Body Mass (g)')

# Show the plot
plt.show()

# %%
# Violin plot of body mass by species and island
plt.figure(figsize=(10,6))

sns.violinplot(data=penguins, x='species', y='body_mass_g', hue='island', split=True, palette='muted')

# Add title and labels
plt.title('Penguin Body Mass Distribution by Species and Island')
plt.xlabel('Species')
plt.ylabel('Body Mass (g)')

# Show the plot
plt.show()

# %%
# Correlation heatmap of numerical features in penguins dataset
plt.figure(figsize=(8,6))

# Drop non-numeric columns before correlation
numeric_data = penguins.drop(columns=['species','island','sex'])

sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")

# Add title
plt.title('Correlation Heatmap of Penguin Features')

# Show the plot
plt.show()

# %%
# Pairplot of penguins dataset
sns.pairplot(data=penguins, hue='species', diag_kind='kde', palette='Set1')

# Show the plot
plt.show()

# %%
# Countplot of penguin species per island
plt.figure(figsize=(8,5))

sns.countplot(data=penguins, x='island', hue='species', palette='Set3')

# Add title and labels
plt.title('Count of Penguin Species per Island')
plt.xlabel('Island')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
# Sex-wise body mass distribution using boxenplot
plt.figure(figsize=(8,5))

sns.boxenplot(data=penguins, x='sex', y='body_mass_g', hue='species', palette='pastel')

# Add title and labels
plt.title('Sex-wise Body Mass Distribution by Species')
plt.xlabel('Sex')
plt.ylabel('Body Mass (g)')

# Show the plot
plt.show()

# %%
# Swarmplot of body mass by species
plt.figure(figsize=(8,5))

sns.swarmplot(data=penguins, x='species', y='body_mass_g', hue='sex', palette='Set2')

# Add title and labels
plt.title('Penguin Body Mass by Species (Swarmplot)')
plt.xlabel('Species')
plt.ylabel('Body Mass (g)')

# Show the plot
plt.show()

# %%
# FacetGrid: Flipper length distribution per species
g = sns.FacetGrid(penguins, col="species", height=4, aspect=1.2)
g.map(sns.histplot, "flipper_length_mm", bins=20, kde=True, color="skyblue")

# Add titles
g.set_axis_labels("Flipper Length (mm)", "Count")
g.set_titles("Species: {col_name}")

plt.show()

# %%
# Jointplot of bill length vs bill depth with species hue
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="scatter", palette="Dark2")

plt.show()

# %%
# 2D KDE plot of bill length vs bill depth
plt.figure(figsize=(7,5))

sns.kdeplot(
    data=penguins, 
    x="bill_length_mm", 
    y="bill_depth_mm", 
    fill=True, 
    cmap="mako", 
    thresh=0.05, 
    levels=15
)

# Add title and labels
plt.title("2D KDE Density Plot: Bill Length vs Bill Depth")
plt.xlabel("Bill Length (mm)")
plt.ylabel("Bill Depth (mm)")

plt.show()

# %%
# Stripplot of flipper length by species
plt.figure(figsize=(8,5))

sns.stripplot(data=penguins, x="species", y="flipper_length_mm", hue="sex", jitter=True, dodge=True, palette="Set1")

# Add title and labels
plt.title("Stripplot: Flipper Length by Species and Sex")
plt.xlabel("Species")
plt.ylabel("Flipper Length (mm)")

plt.show()

# %%
# Lineplot of average body mass vs flipper length
plt.figure(figsize=(8,5))

sns.lineplot(
    data=penguins, 
    x="flipper_length_mm", 
    y="body_mass_g", 
    hue="species", 
    estimator="mean", 
    ci=None, 
    marker="o"
)

# Add title and labels
plt.title("Lineplot: Avg Body Mass vs Flipper Length by Species")
plt.xlabel("Flipper Length (mm)")
plt.ylabel("Body Mass (g)")

plt.show()
# Out:
# C:\Users\Md Faiyaz Khan\AppData\Local\Temp\ipykernel_7584\617454498.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Pointplot of body mass by species and sex
plt.figure(figsize=(8,5))

sns.pointplot(
    data=penguins,
    x="species",
    y="body_mass_g",
    hue="sex",
    dodge=True,
    markers=["o", "s"],
    linestyles=["-", "--"],
    palette="tab10"
)

# Add title and labels
plt.title("Pointplot: Body Mass by Species and Sex")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")

plt.show()

# %%
# Histplot of flipper length with species hue
plt.figure(figsize=(8,5))

sns.histplot(data=penguins, x="flipper_length_mm", hue="species", bins=20, kde=True, palette="muted")

# Add title and labels
plt.title("Histplot: Flipper Length Distribution by Species")
plt.xlabel("Flipper Length (mm)")
plt.ylabel("Count")

plt.show()

# %%
# ECDF plot of body mass by species
plt.figure(figsize=(8,5))

sns.ecdfplot(data=penguins, x="body_mass_g", hue="species", palette="Set2")

# Add title and labels
plt.title("ECDF Plot: Body Mass Distribution by Species")
plt.xlabel("Body Mass (g)")
plt.ylabel("ECDF")

plt.show()

# %%
# Clustermap of correlation matrix
numeric_data = penguins.drop(columns=["species", "island", "sex"]).dropna()

sns.clustermap(
    numeric_data.corr(),
    annot=True,
    cmap="coolwarm",
    figsize=(8,6)
)

plt.show()

# %%
# Lmplot of bill length vs bill depth with regression line by species
sns.lmplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",
    height=5,
    aspect=1.2,
    markers=["o", "s", "D"],
    palette="Dark2"
)

plt.title("LMPlot: Bill Length vs Bill Depth by Species with Regression Line")
plt.show()

# %%
# Residual plot of bill length vs bill depth
plt.figure(figsize=(8,5))

sns.residplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    color="purple"
)

plt.title("Residual Plot: Bill Depth vs Bill Length")
plt.xlabel("Bill Length (mm)")
plt.ylabel("Residuals")
plt.show()

# %%
# Jointplot of bill length vs bill depth
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",
    kind="scatter",
    height=6,
    palette="Set2"
)

plt.show()

# %%
# Jointplot with hexbin style (density heatmap)
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    kind="hex",
    height=6,
    color="teal"
)

plt.show()

# %%
# Rugplot of penguins' bill length
plt.figure(figsize=(8,5))

sns.rugplot(
    data=penguins,
    x="bill_length_mm",
    height=0.1,
    color="blue"
)

# Add title and labels
plt.title("Rugplot: Bill Length Distribution")
plt.xlabel("Bill Length (mm)")
plt.show()

# %%
# Clustermap of penguins numerical features
num_data = penguins[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]].dropna()

sns.clustermap(
    num_data,
    cmap="coolwarm",
    standard_scale=1,
    figsize=(8,6)
)

# %%
# Point plot using catplot: average body mass per species
sns.catplot(
    data=penguins,
    x="species",
    y="body_mass_g",
    kind="point",
    hue="sex",
    errorbar="sd",   # updated instead of ci="sd"
    height=5,
    aspect=1.3
)

plt.title("Point Plot: Body Mass by Species and Sex")
plt.show()

# %%
# FacetGrid: Histogram of flipper length for each species
g = sns.FacetGrid(
    penguins, 
    col="species", 
    hue="sex", 
    height=4, 
    aspect=1
)

# map histogram for each subplot
g.map(sns.histplot, "flipper_length_mm", bins=15, alpha=0.6)

# add legend and titles
g.add_legend()
g.set_axis_labels("Flipper Length (mm)", "Count")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("FacetGrid: Flipper Length Distribution by Species & Sex")

plt.show()

# %%
# PairGrid example
g = sns.PairGrid(
    penguins.dropna(),  # drop NA for clean plotting
    vars=["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"],
    hue="species"
)

# scatter plots for off-diagonal
g.map_offdiag(sns.scatterplot, alpha=0.7)

# histograms for diagonal
g.map_diag(sns.histplot, bins=10, alpha=0.6)

# add legend
g.add_legend()
plt.subplots_adjust(top=0.9)
g.fig.suptitle("PairGrid: Pairwise Relationships of Penguins", fontsize=14)

plt.show()

# %%
# Heatmap of correlation matrix
plt.figure(figsize=(8,6))

# Correlation matrix of penguins numeric columns
corr = penguins.corr(numeric_only=True)

sns.heatmap(
    corr, 
    annot=True,       # show correlation values
    cmap="coolwarm",  # color palette
    center=0,         # middle value
    fmt=".2f"         # format of numbers
)

# Add title
plt.title("Correlation Heatmap of Penguin Features")

plt.show()

# %%
# FacetGrid: Scatter plots of bill length vs bill depth, separated by species
g = sns.FacetGrid(penguins, col="species", hue="sex", height=4, palette="Set1")

# Map scatterplot on each facet
g.map_dataframe(sns.scatterplot, x="bill_length_mm", y="bill_depth_mm")

# Add legend
g.add_legend()

# Add titles
g.set_axis_labels("Bill Length (mm)", "Bill Depth (mm)")
g.fig.suptitle("FacetGrid: Bill Length vs Bill Depth by Species & Sex", y=1.05)

plt.show()

# %%
# Jointplot with hue (scatter only)
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",   # hue allowed with scatter
    kind="scatter",
    height=6,
    palette="Set2"
)

plt.suptitle("Jointplot: Bill Length vs Bill Depth by Species", y=1.02)
plt.show()

# %%
# Pairplot: Visualize pairwise relationships across numerical features
sns.pairplot(
    data=penguins,
    hue="species",        # color by species
    diag_kind="kde",      # kernel density on diagonals instead of hist
    palette="Set2",
    markers=["o", "s", "D"]  # different markers for each species
)

plt.suptitle("Pairplot of Penguin Features by Species", y=1.02)
plt.show()

# %%
# Violin Plot: Distribution of body mass across species (Fixed warning)
plt.figure(figsize=(8,6))

sns.violinplot(
    data=penguins,
    x="species",
    y="body_mass_g",
    hue="species",      # hue assign kiya
    legend=False,       # alag se legend na aaye
    palette="Set2",
    inner="box"
)

plt.title("Violin Plot: Body Mass Distribution by Species")
plt.show()
